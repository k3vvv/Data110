# %% [markdown]
# <a href="https://colab.research.google.com/github/k3vvv/Data110/blob/main/Week_3_Exploring_Temperature_Trends_in_Death_Valley_A_Data_Visualization_Tutorial_Kevin_Miele.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing pandas for data manipulation
import pandas as pd

# Loading the dataset from a URL
df = pd.read_csv("https://raw.githubusercontent.com/Reben80/Data110-32213/e8196b155350595d2c18ddb0ca6c6e1bd9eca344/dataset/tempnormals.csv")

# Creating a DataFrame for Death Valley data
dv = df[df['location'] == 'Death Valley']
dh=df[df['location']=='Houston']
dc=df[df['location']=='Chicago']
ds=df[df['location']=='San Diego']

# Importing matplotlib for visualization
import matplotlib.pyplot as plt

# Calculating the average temperature of Death Valley
descriptive_data_dv = dv['temperature'].describe()
Average_dv = descriptive_data_dv['mean']
print(Average_dv)

# Plotting the temperature data with the average temperature
plt.figure(figsize=(8,5))
plt.style.use('ggplot')

plt.axhline(y=Average_dv, linestyle='--', color='lightblue',label='Average')
plt.plot(dv['day_of_year'], dv['temperature'], label='Death Valley Temperature')
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Trend Temperature in Death Valley',color='orange')
plt.grid(True)
plt.legend(facecolor='darkgray', framealpha=.8)
plt.show()
# Out:
# 77.15382513661201

# %%
# Importing pandas for data manipulation
import pandas as pd

# Loading the dataset from a URL
df = pd.read_csv("https://raw.githubusercontent.com/Reben80/Data110-32213/e8196b155350595d2c18ddb0ca6c6e1bd9eca344/dataset/tempnormals.csv")

# Creating a DataFrame for Houston data
dh = df[df['location'] == 'Houston']

# Importing matplotlib for visualization
import matplotlib.pyplot as plt

# Calculating the average temperature of Houston
descriptive_data_houston = dh['temperature'].describe()
Average_houston = descriptive_data_houston['mean']
print(Average_houston)

# Plotting the temperature data with the average temperature
plt.figure(figsize=(8,5))
plt.style.use('seaborn-darkgrid')

plt.axhline(y=Average_houston, linestyle='--', color='lightgreen', label='Average')
plt.plot(dh['day_of_year'], dh['temperature'], label='Houston Temperature', color='blue')
plt.xlabel('Day of Year')  # Label x-axis
plt.ylabel('Temperature')  # Label y-axis
plt.title('Temperature Trend in Houston')
plt.grid(True)
plt.legend(facecolor='lightgray', framealpha=.8)
plt.show()
# Out:
# 70.24180327868852
# <ipython-input-5-92a7750dcd93>:20: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')  # Change the plot style

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,3))

# Assuming 'df' is your DataFrame and it's already loaded
# Specifying the order of the locations
locations_order_reversed = ['Chicago', 'San Diego', 'Houston', 'Death Valley']

# Grouping the data by location and month, then calculating the average temperature
heatmap_data = df.groupby(['location', 'month'])['temperature'].mean().unstack(level=1)

# Reordering the dataframe based on the reversed location order
heatmap_data_reversed = heatmap_data.reindex(locations_order_reversed)

# Plotting the heatmap

sns.heatmap(heatmap_data_reversed, cmap="YlOrRd", linewidths=0.5, annot=False)
plt.title('Average Monthly Temperature Normals by Location')
plt.xlabel('Month')
plt.ylabel('Location')
plt.show()

# %%
# Step 1: Load Necessary Packages
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Step 2: Create the Numerical Matrix
numerical_matrix = np.random.randint(1, 101, size=(5, 5))

# Step 3: Heatmap Visualization
plt.figure(figsize=(8, 6))
sns.heatmap(numerical_matrix, annot=True, cmap='viridis')
plt.title('Heatmap of a 5x5 Numerical Matrix')
plt.xlabel('Column Index')
plt.ylabel('Row Index')
plt.show()

# %% [markdown]
# - How does the choice of colormap affect the visualization and interpretation of the data?
#
# **The choice of the colormap affects the visualization and interpretation of the data because some colors are brighter than others, which makes it easier to view different levels of temperature or serverity of data. When making a colormap or any other type of data, its always important to assume that others are viewing it for the first time, so you want to incorporate brighter colors to make it stand out. **
#
#
#
# - What insights can you gather from the heatmap about the distribution of values in the numerical matrix?
#
# **The higher the value, the brighter the color, or vice versa. We can also identify regular trends and patterns as well as outliers.   **

# %%
import pandas as pd

# Creating the DataFrame
data = {'Fruit': ['Apple', 'Banana', 'Apple', 'Banana', 'Cherry'],
        'Quantity': [10, 5, 8, 12, 7]}
df = pd.DataFrame(data)

# Grouping by 'Fruit' and then summing the 'Quantity' for each group
grouped_data = df.groupby('Fruit')['Quantity'].sum()

# Display the result
print(grouped_data)
# Out:
# Fruit
# Apple     18
# Banana    17
# Cherry     7
# Name: Quantity, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Houston temperature data from the URL
df_houston = pd.read_csv("https://raw.githubusercontent.com/Reben80/Data110-32213/e8196b155350595d2c18ddb0ca6c6e1bd9eca344/dataset/tempnormals.csv")

# Filter the DataFrame to include only the Houston data
dh = df_houston[df_houston['location'] == 'Houston']

# Set the size of the plot
plt.figure(figsize=(14, 6))

# Group data by location
grouped = df_houston.groupby('location')

# Loop through each location group and plot the temperature against the day of the year
for name, group in grouped:
    plt.plot(group['day_of_year'], group['temperature'], label=name)

# Plot the Houston temperature data
plt.plot(dh['day_of_year'], dh['temperature'], label='Houston', color='red')

# Adding plot title and labels
plt.title('Temperature Trends by Location Throughout the Year')
plt.xlabel('Day of the Year')
plt.ylabel('Temperature')
plt.legend()
plt.grid(True)
plt.show()
